# %%
import gym

# %%
env = gym.make('CartPole-v0')

# %%
env.reset()
# Out:
# array([-0.00041587,  0.01791534, -0.00104807,  0.00288219])

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.n
# Out:
# 2

# %%
env.observation_space.shape[0]
# Out:
# 4

# %%
env.reset()
for t in range(1000):
    random_action = env.action_space.sample()
    env.step(random_action) 
    env.render()
env.close()
env.reset()
# Out:
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\gym\logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# array([ 0.01590937, -0.0041906 ,  0.03429063, -0.00164548])

# %%
for e in range(20):
    # 20 episodes 
    observation = env.reset()
    for t in range(50):
        env.render()
        action = env.action_space.sample()
        observation,reward,done,other_info = env.step(action)
        
        if done:
            # Game Episode is over
            print("Game Episode :{}/{} High Score :{}".format(e,20,t))
            break

env.close()
print("All 20 episodes over!")
# Out:
# Game Episode :0/20 High Score :25
# Game Episode :1/20 High Score :12
# Game Episode :2/20 High Score :16
# Game Episode :3/20 High Score :22
# Game Episode :4/20 High Score :20
# Game Episode :5/20 High Score :18
# Game Episode :6/20 High Score :23
# Game Episode :7/20 High Score :32
# Game Episode :8/20 High Score :28
# Game Episode :9/20 High Score :29
# Game Episode :10/20 High Score :16
# Game Episode :11/20 High Score :36
# Game Episode :12/20 High Score :32
# Game Episode :13/20 High Score :19
# Game Episode :14/20 High Score :27
# Game Episode :15/20 High Score :12
# Game Episode :16/20 High Score :19
# Game Episode :17/20 High Score :17
# Game Episode :18/20 High Score :18
# Game Episode :19/20 High Score :21
# All 20 episodes over!

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import random

# %%
class Agent: 
    def __init__(self,state_size,action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95 # Discount Factor
        self.epsilon = 1.0 # Exploration Rate
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001 
        self.model = self._create_model()
        
    
    def _create_model(self):
        # Neural Network To Approximate Q-Value function
        model = Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu')) 
        model.add(Dense(24,activation='relu')) 
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(loss='mse',optimizer=Adam(lr=self.learning_rate))
        return model
    
    def remember(self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward,next_state,done)) 
        
    def act(self,state):
        if np.random.rand()<=self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state) 
        return np.argmax(act_values[0])
    
    def train(self,batch_size=32): 
        minibatch = random.sample(self.memory,batch_size)
        for state,action,reward,next_state,done in minibatch:
            
            if not done: 
                target = reward + self.gamma*np.amax(self.model.predict(next_state)[0])
            else:
                target = reward
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state,target_f,epochs=1,verbose=0)  
            
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
    
    def load(self,name):
        self.model.load_weights(name)
    def save(self,name):
        self.model.save_weights(name)

# %%
n_episodes = 1000
output_dir = "Cartpole_Model/"

# %%
agent = Agent(state_size=4,action_size=2)
done = False
state_size = 4
action_size =2
batch_size = 32

# %%
agent = Agent(state_size, action_size) 
done = False
for e in range(n_episodes):
    state = env.reset()
    state = np.reshape(state,[1,state_size])
    
    for time in range(5000):
        env.render()
        action = agent.act(state)
        next_state,reward,done,other_info = env.step(action) 
        reward = reward if not done else -10
        next_state = np.reshape(next_state,[1,state_size])
        agent.remember(state,action,reward,next_state,done)
        state = next_state
        
        if done:
            print("Game Episode :{}/{}, High Score:{},Exploration Rate:{:.2}".format(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory)>batch_size:
        agent.train(batch_size)
    
    if e%50==0:
        agent.save(output_dir+"weights_"+'{:04d}'.format(e)+".hdf5")
print("Deep Q-Learner Model Trained.")        
env.close()
# Out:
# Game Episode :0/1000, High Score:18,Exploration Rate:1.0
# Game Episode :1/1000, High Score:18,Exploration Rate:1.0
# Game Episode :2/1000, High Score:39,Exploration Rate:0.99
# Game Episode :3/1000, High Score:39,Exploration Rate:0.99
# Game Episode :4/1000, High Score:18,Exploration Rate:0.99
# Game Episode :5/1000, High Score:24,Exploration Rate:0.98
# Game Episode :6/1000, High Score:25,Exploration Rate:0.98
# Game Episode :7/1000, High Score:19,Exploration Rate:0.97
# Game Episode :8/1000, High Score:12,Exploration Rate:0.97
# Game Episode :9/1000, High Score:17,Exploration Rate:0.96
# Game Episode :10/1000, High Score:50,Exploration Rate:0.96
# Game Episode :11/1000, High Score:13,Exploration Rate:0.95
# Game Episode :12/1000, High Score:36,Exploration Rate:0.95
# Game Episode :13/1000, High Score:12,Exploration Rate:0.94
# Game Episode :14/1000, High Score:27,Exploration Rate:0.94
# Game Episode :15/1000, High Score:12,Exploration Rate:0.93
# Game Episode :16/1000, High Score:10,Exploration Rate:0.93
# Game Episode :17/1000, High Score:32,Exploration Rate:0.92
# Game Episode :18/1000, High Score:21,Exploration Rate:0.92
# Game Episode :19/1000, High Score:23,Exploration Rate:0.91
# Game Episode :20/1000, High Score:10,Exploration Rate:0.91
# Game Episode :21/1000, High Score:25,Exploration Rate:0.9
# Game Episode :22/1000, High Score:57,Exploration Rate:0.9
# Game Episode :23/1000, High Score:16,Exploration Rate:0.9
# Game Episode :24/1000, High Score:23,Exploration Rate:0.89
# Game Episode :25/1000, High Score:15,Exploration Rate:0.89
# Game Episode :26/1000, High Score:16,Exploration Rate:0.88
# Game Episode :27/1000, High Score:31,Exploration Rate:0.88
# Game Episode :28/1000, High Score:42,Exploration Rate:0.87
# Game Episode :29/1000, High Score:16,Exploration Rate:0.87
# Game Episode :30/1000, High Score:57,Exploration Rate:0.86
# Game Episode :31/1000, High Score:32,Exploration Rate:0.86
# Game Episode :32/1000, High Score:14,Exploration Rate:0.86
# Game Episode :33/1000, High Score:9,Exploration Rate:0.85
# Game Episode :34/1000, High Score:10,Exploration Rate:0.85
# Game Episode :35/1000, High Score:15,Exploration Rate:0.84
# Game Episode :36/1000, High Score:49,Exploration Rate:0.84
# Game Episode :37/1000, High Score:25,Exploration Rate:0.83
# Game Episode :38/1000, High Score:22,Exploration Rate:0.83
# Game Episode :39/1000, High Score:24,Exploration Rate:0.83
# Game Episode :40/1000, High Score:18,Exploration Rate:0.82
# Game Episode :41/1000, High Score:12,Exploration Rate:0.82
# Game Episode :42/1000, High Score:21,Exploration Rate:0.81
# Game Episode :43/1000, High Score:20,Exploration Rate:0.81
# Game Episode :44/1000, High Score:19,Exploration Rate:0.81
# Game Episode :45/1000, High Score:31,Exploration Rate:0.8
# Game Episode :46/1000, High Score:21,Exploration Rate:0.8
# Game Episode :47/1000, High Score:12,Exploration Rate:0.79
# Game Episode :48/1000, High Score:16,Exploration Rate:0.79
# Game Episode :49/1000, High Score:16,Exploration Rate:0.79
# Game Episode :50/1000, High Score:15,Exploration Rate:0.78
# Game Episode :51/1000, High Score:12,Exploration Rate:0.78
# Game Episode :52/1000, High Score:15,Exploration Rate:0.77
# Game Episode :53/1000, High Score:14,Exploration Rate:0.77
# Game Episode :54/1000, High Score:39,Exploration Rate:0.77
# Game Episode :55/1000, High Score:8,Exploration Rate:0.76
# Game Episode :56/1000, High Score:16,Exploration Rate:0.76
# Game Episode :57/1000, High Score:16,Exploration Rate:0.76
# Game Episode :58/1000, High Score:11,Exploration Rate:0.75
# Game Episode :59/1000, High Score:29,Exploration Rate:0.75
# Game Episode :60/1000, High Score:11,Exploration Rate:0.74
# Game Episode :61/1000, High Score:10,Exploration Rate:0.74
# Game Episode :62/1000, High Score:14,Exploration Rate:0.74
# Game Episode :63/1000, High Score:14,Exploration Rate:0.73
# Game Episode :64/1000, High Score:12,Exploration Rate:0.73
# Game Episode :65/1000, High Score:13,Exploration Rate:0.73
# Game Episode :66/1000, High Score:55,Exploration Rate:0.72
# Game Episode :67/1000, High Score:31,Exploration Rate:0.72
# Game Episode :68/1000, High Score:9,Exploration Rate:0.71
# Game Episode :69/1000, High Score:26,Exploration Rate:0.71
# Game Episode :70/1000, High Score:13,Exploration Rate:0.71
# Game Episode :71/1000, High Score:9,Exploration Rate:0.7
# Game Episode :72/1000, High Score:11,Exploration Rate:0.7
# Game Episode :73/1000, High Score:13,Exploration Rate:0.7
# Game Episode :74/1000, High Score:13,Exploration Rate:0.69
# Game Episode :75/1000, High Score:16,Exploration Rate:0.69
# Game Episode :76/1000, High Score:12,Exploration Rate:0.69
# Game Episode :77/1000, High Score:13,Exploration Rate:0.68
# Game Episode :78/1000, High Score:12,Exploration Rate:0.68
# Game Episode :79/1000, High Score:28,Exploration Rate:0.68
# Game Episode :80/1000, High Score:16,Exploration Rate:0.67
# Game Episode :81/1000, High Score:12,Exploration Rate:0.67
# Game Episode :82/1000, High Score:20,Exploration Rate:0.67
# Game Episode :83/1000, High Score:42,Exploration Rate:0.66
# Game Episode :84/1000, High Score:76,Exploration Rate:0.66
# Game Episode :85/1000, High Score:28,Exploration Rate:0.66
# Game Episode :86/1000, High Score:22,Exploration Rate:0.65
# Game Episode :87/1000, High Score:39,Exploration Rate:0.65
# Game Episode :88/1000, High Score:21,Exploration Rate:0.65
# Game Episode :89/1000, High Score:34,Exploration Rate:0.64
# Game Episode :90/1000, High Score:21,Exploration Rate:0.64
# Game Episode :91/1000, High Score:21,Exploration Rate:0.64
# Game Episode :92/1000, High Score:16,Exploration Rate:0.63
# Game Episode :93/1000, High Score:14,Exploration Rate:0.63
# Game Episode :94/1000, High Score:23,Exploration Rate:0.63
# Game Episode :95/1000, High Score:29,Exploration Rate:0.62
# Game Episode :96/1000, High Score:33,Exploration Rate:0.62
# Game Episode :97/1000, High Score:18,Exploration Rate:0.62
# Game Episode :98/1000, High Score:24,Exploration Rate:0.61
# Game Episode :99/1000, High Score:23,Exploration Rate:0.61
# Game Episode :100/1000, High Score:19,Exploration Rate:0.61
# Game Episode :101/1000, High Score:12,Exploration Rate:0.61
# Game Episode :102/1000, High Score:33,Exploration Rate:0.6
# Game Episode :103/1000, High Score:14,Exploration Rate:0.6
# Game Episode :104/1000, High Score:13,Exploration Rate:0.6
# Game Episode :105/1000, High Score:12,Exploration Rate:0.59
# Game Episode :106/1000, High Score:27,Exploration Rate:0.59
# Game Episode :107/1000, High Score:38,Exploration Rate:0.59
# Game Episode :108/1000, High Score:33,Exploration Rate:0.58
# Game Episode :109/1000, High Score:30,Exploration Rate:0.58
# Game Episode :110/1000, High Score:21,Exploration Rate:0.58
# Game Episode :111/1000, High Score:15,Exploration Rate:0.58
# Game Episode :112/1000, High Score:13,Exploration Rate:0.57
# Game Episode :113/1000, High Score:54,Exploration Rate:0.57
# Game Episode :114/1000, High Score:29,Exploration Rate:0.57
# Game Episode :115/1000, High Score:60,Exploration Rate:0.56
# Game Episode :116/1000, High Score:21,Exploration Rate:0.56
# Game Episode :117/1000, High Score:29,Exploration Rate:0.56
# Game Episode :118/1000, High Score:20,Exploration Rate:0.56
# Game Episode :119/1000, High Score:16,Exploration Rate:0.55
# Game Episode :120/1000, High Score:33,Exploration Rate:0.55
# Game Episode :121/1000, High Score:23,Exploration Rate:0.55
# Game Episode :122/1000, High Score:40,Exploration Rate:0.55
# Game Episode :123/1000, High Score:89,Exploration Rate:0.54
# Game Episode :124/1000, High Score:25,Exploration Rate:0.54
# Game Episode :125/1000, High Score:86,Exploration Rate:0.54
# Game Episode :126/1000, High Score:18,Exploration Rate:0.53
# Game Episode :127/1000, High Score:22,Exploration Rate:0.53
# Game Episode :128/1000, High Score:57,Exploration Rate:0.53
# Game Episode :129/1000, High Score:88,Exploration Rate:0.53
# Game Episode :130/1000, High Score:31,Exploration Rate:0.52
# Game Episode :131/1000, High Score:62,Exploration Rate:0.52
# Game Episode :132/1000, High Score:71,Exploration Rate:0.52
# Game Episode :133/1000, High Score:34,Exploration Rate:0.52
# Game Episode :134/1000, High Score:24,Exploration Rate:0.51
# Game Episode :135/1000, High Score:28,Exploration Rate:0.51
# Game Episode :136/1000, High Score:33,Exploration Rate:0.51
# Game Episode :137/1000, High Score:17,Exploration Rate:0.51
# Game Episode :138/1000, High Score:53,Exploration Rate:0.5
# Game Episode :139/1000, High Score:27,Exploration Rate:0.5
# Game Episode :140/1000, High Score:18,Exploration Rate:0.5
# Game Episode :141/1000, High Score:30,Exploration Rate:0.5
# Game Episode :142/1000, High Score:15,Exploration Rate:0.49
# Game Episode :143/1000, High Score:21,Exploration Rate:0.49
# Game Episode :144/1000, High Score:30,Exploration Rate:0.49
# Game Episode :145/1000, High Score:20,Exploration Rate:0.49
# Game Episode :146/1000, High Score:19,Exploration Rate:0.48
# Game Episode :147/1000, High Score:21,Exploration Rate:0.48
# Game Episode :148/1000, High Score:45,Exploration Rate:0.48
# Game Episode :149/1000, High Score:104,Exploration Rate:0.48
# Game Episode :150/1000, High Score:31,Exploration Rate:0.47
# Game Episode :151/1000, High Score:24,Exploration Rate:0.47
# Game Episode :152/1000, High Score:37,Exploration Rate:0.47
# Game Episode :153/1000, High Score:35,Exploration Rate:0.47
# Game Episode :154/1000, High Score:58,Exploration Rate:0.46
# Game Episode :155/1000, High Score:22,Exploration Rate:0.46
# Game Episode :156/1000, High Score:22,Exploration Rate:0.46
# Game Episode :157/1000, High Score:37,Exploration Rate:0.46
# Game Episode :158/1000, High Score:45,Exploration Rate:0.46
# Game Episode :159/1000, High Score:19,Exploration Rate:0.45
# Game Episode :160/1000, High Score:27,Exploration Rate:0.45
# Game Episode :161/1000, High Score:12,Exploration Rate:0.45
# Game Episode :162/1000, High Score:18,Exploration Rate:0.45
# Game Episode :163/1000, High Score:17,Exploration Rate:0.44
# Game Episode :164/1000, High Score:45,Exploration Rate:0.44
# Game Episode :165/1000, High Score:32,Exploration Rate:0.44
# Game Episode :166/1000, High Score:9,Exploration Rate:0.44
# Game Episode :167/1000, High Score:61,Exploration Rate:0.44
# Game Episode :168/1000, High Score:24,Exploration Rate:0.43
# Game Episode :169/1000, High Score:18,Exploration Rate:0.43
# Game Episode :170/1000, High Score:15,Exploration Rate:0.43
# Game Episode :171/1000, High Score:13,Exploration Rate:0.43
# Game Episode :172/1000, High Score:19,Exploration Rate:0.42
# Game Episode :173/1000, High Score:18,Exploration Rate:0.42
# Game Episode :174/1000, High Score:15,Exploration Rate:0.42
# Game Episode :175/1000, High Score:12,Exploration Rate:0.42
# Game Episode :176/1000, High Score:9,Exploration Rate:0.42
# Game Episode :177/1000, High Score:24,Exploration Rate:0.41
# Game Episode :178/1000, High Score:19,Exploration Rate:0.41
# Game Episode :179/1000, High Score:10,Exploration Rate:0.41
# Game Episode :180/1000, High Score:31,Exploration Rate:0.41
# Game Episode :181/1000, High Score:70,Exploration Rate:0.41
# Game Episode :182/1000, High Score:26,Exploration Rate:0.4
# Game Episode :183/1000, High Score:56,Exploration Rate:0.4
# Game Episode :184/1000, High Score:51,Exploration Rate:0.4
# Game Episode :185/1000, High Score:25,Exploration Rate:0.4
# Game Episode :186/1000, High Score:17,Exploration Rate:0.4
# Game Episode :187/1000, High Score:15,Exploration Rate:0.39
# Game Episode :188/1000, High Score:8,Exploration Rate:0.39
# Game Episode :189/1000, High Score:18,Exploration Rate:0.39
# Game Episode :190/1000, High Score:34,Exploration Rate:0.39
# Game Episode :191/1000, High Score:26,Exploration Rate:0.39
# Game Episode :192/1000, High Score:20,Exploration Rate:0.38
# Game Episode :193/1000, High Score:23,Exploration Rate:0.38
# Game Episode :194/1000, High Score:27,Exploration Rate:0.38
# Game Episode :195/1000, High Score:20,Exploration Rate:0.38
# Game Episode :196/1000, High Score:18,Exploration Rate:0.38
# Game Episode :197/1000, High Score:39,Exploration Rate:0.37
# Game Episode :198/1000, High Score:65,Exploration Rate:0.37
# Game Episode :199/1000, High Score:64,Exploration Rate:0.37
# Game Episode :200/1000, High Score:20,Exploration Rate:0.37
# Game Episode :201/1000, High Score:24,Exploration Rate:0.37
# Game Episode :202/1000, High Score:164,Exploration Rate:0.37
# Game Episode :203/1000, High Score:94,Exploration Rate:0.36
# Game Episode :204/1000, High Score:141,Exploration Rate:0.36
# Game Episode :205/1000, High Score:76,Exploration Rate:0.36
# Game Episode :206/1000, High Score:24,Exploration Rate:0.36
# Game Episode :207/1000, High Score:26,Exploration Rate:0.36
# Game Episode :208/1000, High Score:44,Exploration Rate:0.35
# Game Episode :209/1000, High Score:37,Exploration Rate:0.35
# Game Episode :210/1000, High Score:54,Exploration Rate:0.35
# Game Episode :211/1000, High Score:117,Exploration Rate:0.35
# Game Episode :212/1000, High Score:40,Exploration Rate:0.35
# Game Episode :213/1000, High Score:21,Exploration Rate:0.35
# Game Episode :214/1000, High Score:28,Exploration Rate:0.34
# Game Episode :215/1000, High Score:18,Exploration Rate:0.34
# Game Episode :216/1000, High Score:12,Exploration Rate:0.34
# Game Episode :217/1000, High Score:21,Exploration Rate:0.34
# Game Episode :218/1000, High Score:27,Exploration Rate:0.34
# Game Episode :219/1000, High Score:25,Exploration Rate:0.34
# Game Episode :220/1000, High Score:21,Exploration Rate:0.33
# Game Episode :221/1000, High Score:29,Exploration Rate:0.33
# Game Episode :222/1000, High Score:103,Exploration Rate:0.33
# Game Episode :223/1000, High Score:30,Exploration Rate:0.33
# Game Episode :224/1000, High Score:16,Exploration Rate:0.33
# Game Episode :225/1000, High Score:14,Exploration Rate:0.33
# Game Episode :226/1000, High Score:16,Exploration Rate:0.32
# Game Episode :227/1000, High Score:23,Exploration Rate:0.32
# Game Episode :228/1000, High Score:36,Exploration Rate:0.32
# Game Episode :229/1000, High Score:35,Exploration Rate:0.32
# Game Episode :230/1000, High Score:52,Exploration Rate:0.32
# Game Episode :231/1000, High Score:40,Exploration Rate:0.32
# Game Episode :232/1000, High Score:47,Exploration Rate:0.31
# Game Episode :233/1000, High Score:56,Exploration Rate:0.31
# Game Episode :234/1000, High Score:18,Exploration Rate:0.31
# Game Episode :235/1000, High Score:24,Exploration Rate:0.31
# Game Episode :236/1000, High Score:30,Exploration Rate:0.31
# Game Episode :237/1000, High Score:21,Exploration Rate:0.31
# Game Episode :238/1000, High Score:35,Exploration Rate:0.3
# Game Episode :239/1000, High Score:85,Exploration Rate:0.3
# Game Episode :240/1000, High Score:199,Exploration Rate:0.3
# Game Episode :241/1000, High Score:25,Exploration Rate:0.3
# Game Episode :242/1000, High Score:78,Exploration Rate:0.3
# Game Episode :243/1000, High Score:85,Exploration Rate:0.3
# Game Episode :244/1000, High Score:62,Exploration Rate:0.3
# Game Episode :245/1000, High Score:105,Exploration Rate:0.29
# Game Episode :246/1000, High Score:39,Exploration Rate:0.29
# Game Episode :247/1000, High Score:68,Exploration Rate:0.29
# Game Episode :248/1000, High Score:120,Exploration Rate:0.29
# Game Episode :249/1000, High Score:82,Exploration Rate:0.29
# Game Episode :250/1000, High Score:42,Exploration Rate:0.29
# Game Episode :251/1000, High Score:85,Exploration Rate:0.29
# Game Episode :252/1000, High Score:77,Exploration Rate:0.28
# Game Episode :253/1000, High Score:52,Exploration Rate:0.28
# Game Episode :254/1000, High Score:125,Exploration Rate:0.28
# Game Episode :255/1000, High Score:93,Exploration Rate:0.28
# Game Episode :256/1000, High Score:93,Exploration Rate:0.28
# Game Episode :257/1000, High Score:49,Exploration Rate:0.28
# Game Episode :258/1000, High Score:84,Exploration Rate:0.28
# Game Episode :259/1000, High Score:199,Exploration Rate:0.27
# Game Episode :260/1000, High Score:199,Exploration Rate:0.27
# Game Episode :261/1000, High Score:199,Exploration Rate:0.27
# Game Episode :262/1000, High Score:199,Exploration Rate:0.27
# Game Episode :263/1000, High Score:138,Exploration Rate:0.27
# Game Episode :264/1000, High Score:140,Exploration Rate:0.27
# Game Episode :265/1000, High Score:144,Exploration Rate:0.27
# Game Episode :266/1000, High Score:142,Exploration Rate:0.26
# Game Episode :267/1000, High Score:155,Exploration Rate:0.26
# Game Episode :268/1000, High Score:157,Exploration Rate:0.26
# Game Episode :269/1000, High Score:199,Exploration Rate:0.26
# Game Episode :270/1000, High Score:92,Exploration Rate:0.26
# Game Episode :271/1000, High Score:122,Exploration Rate:0.26
# Game Episode :272/1000, High Score:199,Exploration Rate:0.26
# Game Episode :273/1000, High Score:58,Exploration Rate:0.26
# Game Episode :274/1000, High Score:151,Exploration Rate:0.25
# Game Episode :275/1000, High Score:199,Exploration Rate:0.25
# Game Episode :276/1000, High Score:91,Exploration Rate:0.25
# Game Episode :277/1000, High Score:131,Exploration Rate:0.25
# Game Episode :278/1000, High Score:199,Exploration Rate:0.25
# Game Episode :279/1000, High Score:173,Exploration Rate:0.25
# Game Episode :280/1000, High Score:171,Exploration Rate:0.25
# Game Episode :281/1000, High Score:199,Exploration Rate:0.25
# Game Episode :282/1000, High Score:199,Exploration Rate:0.24
# Game Episode :283/1000, High Score:199,Exploration Rate:0.24
# Game Episode :284/1000, High Score:199,Exploration Rate:0.24
# Game Episode :285/1000, High Score:199,Exploration Rate:0.24
# Game Episode :286/1000, High Score:180,Exploration Rate:0.24
# Game Episode :287/1000, High Score:178,Exploration Rate:0.24
# Game Episode :288/1000, High Score:166,Exploration Rate:0.24
# Game Episode :289/1000, High Score:199,Exploration Rate:0.24
# Game Episode :290/1000, High Score:185,Exploration Rate:0.23
# Game Episode :291/1000, High Score:139,Exploration Rate:0.23
# Game Episode :292/1000, High Score:188,Exploration Rate:0.23
# Game Episode :293/1000, High Score:199,Exploration Rate:0.23
# Game Episode :294/1000, High Score:165,Exploration Rate:0.23
# Game Episode :295/1000, High Score:176,Exploration Rate:0.23
# Game Episode :296/1000, High Score:199,Exploration Rate:0.23
# Game Episode :297/1000, High Score:174,Exploration Rate:0.23
# Game Episode :298/1000, High Score:199,Exploration Rate:0.23
# Game Episode :299/1000, High Score:177,Exploration Rate:0.22
# Game Episode :300/1000, High Score:199,Exploration Rate:0.22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-da6a6972404e> in <module>
#      19
#      20     if len(agent.memory)>batch_size:
# ---> 21         agent.train(batch_size)
#      22
#      23     if e%50==0:
#
# <ipython-input-12-8ac177dfcb01> in train(self, batch_size)
#      35
#      36             if not done:
# ---> 37                 target = reward + self.gamma*np.amax(self.model.predict(next_state)[0])
#      38             else:
#      39                 target = reward
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1567     with self.distribute_strategy.scope():
#    1568       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1569       data_handler = data_adapter.DataHandler(
#    1570           x=x,
#    1571           batch_size=batch_size,
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1103
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#    1107         y,
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     360       return flat_dataset
#     361
# --> 362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
#     364     dataset = self.slice_inputs(indices_dataset, inputs)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func)
#    1725       Dataset: A `Dataset`.
#    1726     """
# -> 1727     return FlatMapDataset(self, map_func)
#    1728
#    1729   def interleave(self,
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func)
#    4120     """See `Dataset.flat_map()` for details."""
#    4121     self._input_dataset = input_dataset
# -> 4122     self._map_func = StructuredFunctionWrapper(
#    4123         map_func, self._transformation_name(), dataset=input_dataset)
#    4124     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3369       with tracking.resource_tracker_scope(resource_tracker):
#    3370         # TODO(b/141462134): Switch to using garbage collection.
# -> 3371         self._function = wrapper_fn.get_concrete_function()
#    3372         if add_to_graph:
#    3373           self._function.add_to_graph(ops.get_default_graph())
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    2936       **kwargs: inputs to specialize on.
#    2937     """
# -> 2938     graph_function = self._get_concrete_function_garbage_collected(
#    2939         *args, **kwargs)
#    2940     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2904       args, kwargs = None, None
#    2905     with self._lock:
# -> 2906       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2907       seen_names = set()
#    2908       captured = object_identity.ObjectIdentitySet(
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    3362           attributes=defun_kwargs)
#    3363       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3364         ret = _wrapper_helper(*args)
#    3365         ret = structure.to_tensor_list(self._output_structure, ret)
#    3366         return [ops.convert_to_tensor(t) for t in ret]
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    3292     def _wrapper_helper(*args):
#    3293       """Wrapper for passing nested structures to and from tf.data functions."""
# -> 3294       nested_args = structure.from_compatible_tensor_list(
#    3295           self._input_structure, args)
#    3296       if not _should_unpack_args(nested_args):
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\util\structure.py in from_compatible_tensor_list(element_spec, tensor_list)
#     226   # pylint: disable=protected-access
#     227   # pylint: disable=g-long-lambda
# --> 228   return _from_tensor_list_helper(
#     229       lambda spec, value: spec._from_compatible_tensor_list(value),
#     230       element_spec, tensor_list)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\util\structure.py in _from_tensor_list_helper(decode_fn, element_spec, tensor_list)
#     203   for (component_spec, num_flat_values) in zip(flat_specs, flat_spec_lengths):
#     204     value = tensor_list[i:i + num_flat_values]
# --> 205     flat_ret.append(decode_fn(component_spec, value))
#     206     i += num_flat_values
#     207   return nest.pack_sequence_as(element_spec, flat_ret)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\data\util\structure.py in <lambda>(spec, value)
#     227   # pylint: disable=g-long-lambda
#     228   return _from_tensor_list_helper(
# --> 229       lambda spec, value: spec._from_compatible_tensor_list(value),
#     230       element_spec, tensor_list)
#     231
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\tensor_spec.py in _from_compatible_tensor_list(self, tensor_list)
#     175     # information.
#     176     assert len(tensor_list) == 1
# --> 177     tensor_list[0].set_shape(self._shape)
#     178     return tensor_list[0]
#     179
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\ops.py in set_shape(self, shape)
#     746           dim_list.append(dim.value)
#     747     try:
# --> 748       pywrap_tf_session.TF_GraphSetTensorShape_wrapper(
#     749           self._op._graph._c_graph,  # pylint: disable=protected-access
#     750           self._as_tf_output(),
#
# KeyboardInterrupt:
